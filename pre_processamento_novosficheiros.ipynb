# %%
import pandas as pd

# Abrir a folha 2 da tabela de acidentes
df = pd.read_excel('Tabela_Acidentes_2018.xlsx', sheet_name=1)  # 1 = segunda folha (índice começa em 0)

# Mostrar os nomes das colunas para identificar o nome correto
print("Colunas do arquivo:")
print(df.columns.tolist())
print("\n")
# Out:
# Colunas do arquivo:
# ['Id. Acidente', 'Datahora', 'Mês', 'Hora', 'Dia da Semana', 'Distrito', 'Concelho', 'Freguesia', 'Tipos Vias', 'Nome arruamento', 'Cod Via', 'Nome Outra Via', 'Km', 'Latitude GPS', 'Longitude GPS', '# Veículos Envolvidos ', '# Veículos Ligeiros ', '# Veículos Pesados', '# Ciclomotores / Motociclos', '# Outros Veículos', '# vias de trânsito no sentido', 'Vítimas mortais 30 dias', 'Feridos graves 30 dias', 'Feridos leves 30 dias', 'Velocidade local', 'Características Técnicas', 'Desc. Esquema', 'Estado Conservação', 'Factores Atmosféricos', 'Reg Circulação1', 'Intersecção Vias', 'Localizações', 'Luminosidade', 'Marca Via', 'Natureza', 'Obras Arte', 'Obstáculos', 'Sentidos', 'Sinais', 'Sinais Luminosos', 'Tipo Piso', 'Traçado 1', 'Traçado 2', 'Traçado 3', 'Traçado 4', 'Via Trânsito', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52']

# %%
# Dicionários de mapeamento para todas as colunas

#Características Tecnicas
mapeamento_caract_tecnicas = {
    0: 'NÃO DEFINIDO',
    1: 'Autoestrada',
    2: 'Outra via',
    3: 'Estrada sem separador'
}

#desc. Esquema
mapeamento_desc_esquema = {
    'A1': 'Acid. c/ peões - A1',
    'A2': 'Acid. c/ peões - A2',
    'A3': 'Acid. c/ peões - A3',
    'A4': 'Acid. c/ peões - A4',
    'A5': 'Acid. c/ peões - A5',
    'A6': 'Acid. c/ peões - A6',
    'A7': 'Acid. c/ peões - A7',
    'A8': 'Acid. c/ peões - A8',
    'A9': 'Acid. c/ peões - A9',
    'A0': 'Acid. c/ peões - A0',
    'B1': 'Acid. c/ veíc. Estacionados - B1',
    'B2': 'Acid. c/ veíc. Estacionados - B2',
    'B3': 'Acid. c/ veíc. Estacionados - B3',
    'B4': 'Acid. c/ veíc. Estacionados - B4',
    'C1': 'Acid. só c/ 1 veíc. e obst., animais, etc. - C1',
    'C2': 'Acid. só c/ 1 veíc. e obst., animais, etc. - C2',
    'C3': 'Acid. só c/ 1 veíc. e obst., animais, etc. - C3',
    'C4': 'Acid. só c/ 1 veíc. e obst., animais, etc. - C4',
    'C5': 'Acid. só c/ 1 veíc. e obst., animais, etc. - C5',
    'D1': 'Acid. só c/ 1 veíc. s/ obst., animais, etc. - D1',
    'D2': 'Acid. só c/ 1 veíc. s/ obst., animais, etc. - D2',
    'D3': 'Acid. só c/ 1 veíc. s/ obst., animais, etc. - D3',
    'D4': 'Acid. só c/ 1 veíc. s/ obst., animais, etc. - D4',
    'D5': 'Acid. só c/ 1 veíc. s/ obst., animais, etc. - D5',
    'D6': 'Acid. só c/ 1 veíc. s/ obst., animais, etc. - D6',
    'D7': 'Acid. só c/ 1 veíc. s/ obst., animais, etc. - D7',
    'E1': 'Acid. c/ 2 ou mais veíc. - s/ mudança direcção - mesmo sentido - E1',
    'E2': 'Acid. c/ 2 ou mais veíc. - s/ mudança direcção - mesmo sentido - E2',
    'E3': 'Acid. c/ 2 ou mais veíc. - s/ mudança direcção - mesmo sentido - E3',
    'E4': 'Acid. c/ 2 ou mais veíc. - s/ mudança direcção - mesmo sentido - E4',
    'E5': 'Acid. c/ 2 ou mais veíc. - s/ mudança direcção - mesmo sentido - E5',
    'E6': 'Acid. c/ 2 ou mais veíc. - s/ mudança direcção - mesmo sentido - E6',
    'F1': 'Acid. c/ 2 ou mais veíc. - s/ mudança direcção - sentido contrário - F1',
    'F2': 'Acid. c/ 2 ou mais veíc. - s/ mudança direcção - sentido contrário - F2',
    'F3': 'Acid. c/ 2 ou mais veíc. - s/ mudança direcção - sentido contrário - F3',
    'F4': 'Acid. c/ 2 ou mais veíc. - s/ mudança direcção - sentido contrário - F4',
    'G1': 'Acid. c/ 2 ou mais veíc. - mudança direcção - mesma via - mesmo sentido - G1',
    'G2': 'Acid. c/ 2 ou mais veíc. - mudança direcção - mesma via - mesmo sentido - G2',
    'G3': 'Acid. c/ 2 ou mais veíc. - mudança direcção - mesma via - mesmo sentido - G3',
    'G4': 'Acid. c/ 2 ou mais veíc. - mudança direcção - mesma via - mesmo sentido - G4',
    'G5': 'Acid. c/ 2 ou mais veíc. - mudança direcção - mesma via - mesmo sentido - G5',
    'G6': 'Acid. c/ 2 ou mais veíc. - mudança direcção - mesma via - mesmo sentido - G6',
    'G7': 'Acid. c/ 2 ou mais veíc. - mudança direcção - mesma via - mesmo sentido - G7',
    'H1': 'Acid. c/ 2 ou mais veíc. - mudança direcção - mesma via - sentido contrário - H1',
    'H2': 'Acid. c/ 2 ou mais veíc. - mudança direcção - mesma via - sentido contrário - H2',
    'H3': 'Acid. c/ 2 ou mais veíc. - mudança direcção - mesma via - sentido contrário - H3',
    'H4': 'Acid. c/ 2 ou mais veíc. - mudança direcção - mesma via - sentido contrário - H4',
    'H5': 'Acid. c/ 2 ou mais veíc. - mudança direcção - mesma via - sentido contrário - H5',
    'H6': 'Acid. c/ 2 ou mais veíc. - mudança direcção - mesma via - sentido contrário - H6',
    'I1': 'Acid. c/ 2 ou mais veíc. - vias diferentes - I1',
    'I2': 'Acid. c/ 2 ou mais veíc. - vias diferentes - I2',
    'I3': 'Acid. c/ 2 ou mais veíc. - vias diferentes - I3',
    'I4': 'Acid. c/ 2 ou mais veíc. - vias diferentes - I4',
    'I5': 'Acid. c/ 2 ou mais veíc. - vias diferentes - I5',
    'I6': 'Acid. c/ 2 ou mais veíc. - vias diferentes - I6',
    'I7': 'Acid. c/ 2 ou mais veíc. - vias diferentes - I7',
    'I8': 'Acid. c/ 2 ou mais veíc. - vias diferentes - I8',
    '0': 'NÃO DEFINIDO'
}

#estado conservação

mapeamento_estado_conservacao = {
    0: 'NÃO DEFINIDO',
    1: 'Bom estado',
    2: 'Em estado regular',
    3: 'Em mau estado'
}
# Condições de Aderência
mapeamento_cond_aderencia = {
    0: 'NÃO DEFINIDO',
    1: 'Seco e limpo',
    2: 'Húmido',
    3: 'Molhado',
    4: 'Com água acumulada na faixa de rodagem',
    5: 'Com gelo, geada ou neve',
    6: 'Com lama',
    7: 'Com gravilha ou areia',
    8: 'Com óleo'
}

# Tipos de Vias
mapeamento_tipos_vias = {
    0: 'NÃO DEFINIDO',
    1: 'EM - Estrada Municipal',
    2: 'EN - Estrada Nacional',
    3: 'A  - Auto-Estrada',
    4: 'IC - Itinerário Complementar',
    5: 'IP - Itinerário Principal',
    6: 'Arruamento',
    7: 'EF - Estrada Florestal',
    8: 'Outra Via',
    11: 'VAR -Variante',
    12: 'PNT - Ponte',
    13: 'ER - Estrada Regional'
}

# Factores Atmosféricos
mapeamento_factores_atmosf = {
    0: 'NÃO DEFINIDO',
    1: 'Bom tempo',
    2: 'Chuva',
    3: 'Vento Forte',
    4: 'Nevoeiro',
    5: 'Neve',
    6: 'Nuvem de fumo',
    7: 'Granizo'
}

# Regulação de Circulação
mapeamento_reg_circulacao = {
    0: 'NÃO DEFINIDO',
    1: 'Sentido único',
    2: 'Dois sentidos',
    3: 'Reversível'
   
}

# Intersecção de Vias
mapeamento_interseccao = {
    0: 'NÃO DEFINIDO',
    1: 'Fora da intersecção',
    2: 'Em Cruzamento',
    3: 'Em Entroncamento',
    4: 'Em Rotunda',
    5: 'Em Passagem de nível',
    6: 'Em via de aceleração',
    7: 'Em via de desaceleração',
    8: 'Em ramo de ligação - entrada',
    9: 'Em ramo de ligação - saída'
}

# Localizações
mapeamento_localizacoes = {
    0: 'NÃO DEFINIDO',
    2: 'Dentro das localidades',
    1: 'Fora das localidades'
}

# Luminosidade
mapeamento_luminosidade = {
    0: 'NÃO DEFINIDO',
    1: 'Pleno dia',
    2: 'Crepúsculo',
    3: 'Noite, sem iluminação',
    4: 'Noite, com iluminação',
    5: 'Noite, iluminação desconhecida'
}

# Marca Via
mapeamento_marca_via = {
    0: 'NÃO DEFINIDO',
    1: 'Sem marcas rodoviárias ou pouco visíveis',
    2: 'Com marcas - separadores de sentido de trânsito',
    3: 'Com marcas - separadores de sentido e de vias de trânsito'
}

# Natureza
mapeamento_natureza = {
    0: 'NÃO DEFINIDO',
    1: 'Despiste simples',
    2: 'Despiste com dispositivo de retenção',
    3: 'Despiste sem dispositivo de retenção',
    4: 'Despiste com transposição do dispositivo de retenção lateral',
    5: 'Despiste com capotamento',
    6: 'Despiste com colisão com veículo imobil. ou obstáculo',
    7: 'Despiste com fuga',
    8: 'Colisão frontal',
    9: 'Colisão traseira com outro veículo em movimento',
    10: 'Colisão lateral com outro veículo em movimento',
    11: 'Colisão com veículo ou obstáculo na faixa de rodagem',
    12: 'Colisão choque em cadeia',
    13: 'Colisão com fuga',
    14: 'Colisão com outras situações',
    15: 'Atropelamento de peões',
    16: 'Atropelamento de animais',
    17: 'Atropelamento com fuga'
}

# Obras de Arte
mapeamento_obras_arte = {
    0: 'NÃO DEFINIDO',
    1: 'Túnel',
    2: 'Viaduto/Ponte',
    3: 'Passagem estreita'

}

# Obstáculos
mapeamento_obstaculos = {
    0: 'NÃO DEFINIDO',
    1: 'Inexistentes',
    2: 'Não sinalizados',
    3: 'Insuficentemente sinalizados',
    4: 'Correctamente sinalizados',

}

# Sentidos
mapeamento_sentidos = {
    0: 'NÃO DEFINIDO',
    1: 'No sentido crescente da quilometragem',
    2: 'No sentido decrescente da quilometragem'

}

# Sinais
mapeamento_sinais = {
    0: 'NÃO DEFINIDO',
    1: 'Stop',
    2: 'Cedência de passagem',
    3: 'Proibição de ultrapassagem',
    4: 'Passagem de peões',
    5: 'Outros'
}

# Sinais Luminosos
mapeamento_sinais_luminosos = {
    0: 'NÃO DEFINIDO',
    1: 'Inexistentes',
    2: 'A funcionar normalmente',
    3: 'Intermitente',
    4: 'Desligada'

}

# Tipo de Piso
mapeamento_tipo_piso = {
    0: 'NÃO DEFINIDO',
    1: 'Terra batida',
    2: 'Betuminoso',
    3: 'Betão de cimento',
    4: 'Calçada'
}

# Traçado 1
mapeamento_tracado1 = {
    0: 'NÃO DEFINIDO',
    1: 'Recta',
    2: 'Curva'
}

# Traçado 2
mapeamento_tracado2 = {
    0: 'NÃO DEFINIDO',
    1: 'Em patamar',
    2: 'Com inclinação',
    3: 'Em Lomba'
}
# Traçado 3
mapeamento_tracado3 = {
    0: 'NÃO DEFINIDO',
    1: 'Sem berma ou impraticável',
    2: 'Berma não pavimentada',
    3: 'Berma pavimentada'
}
# Traçado 4
mapeamento_tracado4 = {
    0: 'NÃO DEFINIDO',
    1: 'Em plena via',
    2: 'Na berma',
    3: 'No passeio',
    4: 'Em via ou pista reservada',
    5: 'Em parque de estacionamento'
}

# Via de Trânsito
mapeamento_via_transito = {
    0: 'NÃO DEFINIDO',
    1: 'Esquerda',
    2: 'Direita',
    3: 'Central'
}

print("Todos os dicionários de mapeamento criados!")
# Out:
# Todos os dicionários de mapeamento criados!

# %%
# Aplicar todas as transformações

# Dicionário com todas as colunas e seus respectivos mapeamentos
colunas_mapeamentos = {
    'Características Técnicas': mapeamento_caract_tecnicas,
    'Desc. Esquema': mapeamento_desc_esquema,
    'Estado Conservação': mapeamento_estado_conservacao,
    'Cond Aderência': mapeamento_cond_aderencia,
    'Tipos Vias': mapeamento_tipos_vias,
    'Factores Atmosféricos': mapeamento_factores_atmosf,
    'Reg Circulação1': mapeamento_reg_circulacao,
    'Intersecção Vias': mapeamento_interseccao,
    'Localizações': mapeamento_localizacoes,
    'Luminosidade': mapeamento_luminosidade,
    'Marca Via': mapeamento_marca_via,
    'Natureza': mapeamento_natureza,
    'Obras Arte': mapeamento_obras_arte,
    'Obstáculos': mapeamento_obstaculos,
    'Sentidos': mapeamento_sentidos,
    'Sinais': mapeamento_sinais,
    'Sinais Luminosos': mapeamento_sinais_luminosos,
    'Tipo Piso': mapeamento_tipo_piso,
    'Traçado 1': mapeamento_tracado1,
    'Traçado 2': mapeamento_tracado2,
    'Traçado 3': mapeamento_tracado3,
    'Traçado 4': mapeamento_tracado4,
    'Via Trânsito': mapeamento_via_transito
}

# Aplicar transformações para cada coluna
colunas_transformadas = []
colunas_nao_encontradas = []

for nome_coluna, mapeamento in colunas_mapeamentos.items():
    if nome_coluna in df.columns:
        if df[nome_coluna].dtype in ['int64', 'float64', 'int32']:
            df[nome_coluna] = df[nome_coluna].map(mapeamento)
        else:
            df[nome_coluna] = df[nome_coluna].apply(
                lambda x: mapeamento.get(int(x), x) if str(x).isdigit() else x
            )
        colunas_transformadas.append(nome_coluna)
    else:
        colunas_nao_encontradas.append(nome_coluna)

print(f"✓ Transformadas {len(colunas_transformadas)} colunas:")
for col in colunas_transformadas:
    print(f"  - {col}")

if colunas_nao_encontradas:
    print(f"\n⚠ {len(colunas_nao_encontradas)} colunas não encontradas:")
    for col in colunas_nao_encontradas:
        print(f"  - {col}")
# Out:
# ✓ Transformadas 22 colunas:
#   - Características Técnicas
#   - Desc. Esquema
#   - Estado Conservação
#   - Tipos Vias
#   - Factores Atmosféricos
#   - Reg Circulação1
#   - Intersecção Vias
#   - Localizações
#   - Luminosidade
#   - Marca Via
#   - Natureza
#   - Obras Arte
#   - Obstáculos
#   - Sentidos
#   - Sinais
#   - Sinais Luminosos
#   - Tipo Piso
#   - Traçado 1
#   - Traçado 2
#   - Traçado 3
#   - Traçado 4
#   - Via Trânsito
#
# ⚠ 1 colunas não encontradas:
#   - Cond Aderência

# %%
# export to multiple yearly files
for year in [2018, 2019, 2020,2021, 2022, 2023]:
    df.to_excel(f'Tabela_acidentes_{year}_limpo.xlsx', index=False, engine='openpyxl')
